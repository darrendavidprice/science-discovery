# %% [markdown]
# # Ste's first notebook: analyse Darren's DM paper using yaml files

# %% [markdown]
# ### We are going to look at the DM paper and make some plots from its yaml files. We will use some intuitive containers which make our lives as easy as possible. The workflow is "load dataset --> associate each table of interest with a unique key (this allows us to correlate data between different tables) --> make validation plots." The containers can load data from multiple files, and in the future, multiple formats, allowing easy comparison of e.g. ROOT plots with yaml tables.

# %% [markdown]
# #### First step: import libraries

# %%
import os, sys, yaml
import general_utils.messaging as msg
import general_utils.helpers as hlp
import HEP_data_utils.helpers as HEPData_hlp
from HEP_data_utils.data_structures import *

# %% [markdown]
# #### Create a new "Distribution_store", and populate it with the contents of the yaml files

# %%
dataset = Distribution_store("Darren DM paper")
HEPData_hlp.load_dataset ( dataset , "../HEP_datasets/HEPData-ins1609448-v2-yaml/" )
# Out:
# INFO	HEP_data_utils.helpers.load_dataset	../HEP_datasets/HEPData-ins1609448-v2-yaml is a directory... I am expanding the entries (but will only go one directory deep!)
# INFO	HEP_data_utils.helpers.load_dataset	submission.yaml file found in directory ../HEP_datasets/HEPData-ins1609448-v2-yaml... I will use this to steer the directory

# %% [markdown]
# #### Now look at the automatically-generated keys for each distribution...

# %%
dataset.print_keys()
# Out:
# INFO	Distribution_store.print_keys	keys for _distributions_1D are:
# |10.17182/hepdata.78366.v2/t1|Table1.yaml|measured $R^\text{miss}$|
# |10.17182/hepdata.78366.v2/t1|Table1.yaml|expected $R^\text{miss}$|
# |10.17182/hepdata.78366.v2/t1|Table1.yaml|$\text{d}\sigma / \text{d} p_\text{T}^\text{miss} $ (SM prediction for numerator)|
# |10.17182/hepdata.78366.v2/t1|Table1.yaml|$\text{d}\sigma / \text{d} p_\text{T}^\text{miss} $ (SM prediction for denominator)|
# |10.17182/hepdata.78366.v2/t2|Table2.yaml|measured $R^\text{miss}$|
# |10.17182/hepdata.78366.v2/t2|Table2.yaml|expected $R^\text{miss}$|
# |10.17182/hepdata.78366.v2/t2|Table2.yaml|$\text{d}\sigma / \text{d} p_\text{T}^\text{miss} $ (SM prediction for numerator)|
# |10.17182/hepdata.78366.v2/t2|Table2.yaml|$\text{d}\sigma / \text{d} p_\text{T}^\text{miss} $ (SM prediction for denominator)|
# |10.17182/hepdata.78366.v2/t3|Table3.yaml|measured $R^\text{miss}$|
# |10.17182/hepdata.78366.v2/t3|Table3.yaml|expected $R^\text{miss}$|
# |10.17182/hepdata.78366.v2/t3|Table3.yaml|$\text{d}\sigma / \text{d} m_\text{jj} $ (SM prediction for numerator)|
# |10.17182/hepdata.78366.v2/t3|Table3.yaml|$\text{d}\sigma / \text{d} m_\text{jj} $ (SM prediction for denominator)|
# |10.17182/hepdata.78366.v2/t4|Table4.yaml|measured $R^\text{miss}$|
# |10.17182/hepdata.78366.v2/t4|Table4.yaml|expected $R^\text{miss}$|
# |10.17182/hepdata.78366.v2/t4|Table4.yaml|$\text{d}\sigma / \text{d} \Delta\phi_\text{jj} $ (SM prediction for numerator)|
# |10.17182/hepdata.78366.v2/t4|Table4.yaml|$\text{d}\sigma / \text{d} \Delta\phi_\text{jj} $ (SM prediction for denominator)|
# INFO	Distribution_store.print_keys	keys for _distributions_2D are:
# |10.17182/hepdata.78366.v2/t5|Table5.yaml|Statistical-only correlation|
# |10.17182/hepdata.78366.v2/t6|Table6.yaml|Statistical-only covariance|
# |10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|
# |10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;1
# |10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;2
# |10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;3
# |10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;4
# |10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;5
# |10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;6
# |10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;7
# |10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;8
# |10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;9
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t5|Table5.yaml|Statistical-only correlation|] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t6|Table6.yaml|Statistical-only covariance|] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;1] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;2] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;3] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;4] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;5] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;6] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;7] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;8] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=|10.17182/hepdata.78366.v2/t7|Table7.yaml|Systematic covariance|-duplicated-auto-key;9] with local-keys: []

# %% [markdown]
# #### Success - we found all of the tables stored within this directory. The automatic keys are designed to be unique and specify where the distribution was found. They have the format "|table-doi|file|heading within file|", and a suffix "-duplicated-auto-key;N" is added when multiple entries have the same key. These are not very nice to use... but fortunately we stored all possible metadata for each table. If we print this, it should give us some idea about what the table is.

# %%
dataset.print_meta("|10.17182/hepdata.78366.v2/t1|Table1.yaml|measured $R^\\text{miss}$|")
# Out:
# INFO	Distribution.print_meta	printing all metadata for object measured $R^\text{miss}$
# LOCAL::data_file   :   Table1.yaml
# LOCAL::description   :   Measured and expected $R^\text{miss}$ as a function of $p_\text{T}^\text{miss}$ in the $\geq 1$ jet phase space. The fiducial SM predictions for the numerator and the denominator are also given.
# LOCAL::keywords   :   [{'name': 'reactions', 'values': ['P P --> MET + J X', 'P P --> LEPTON+ LEPTON- J X']}, {'name': 'observables', 'values': ['PTMISS']}, {'name': 'cmenergies', 'values': [13000.0]}, {'name': 'phrases', 'values': ['Dark Matter', 'Fiducial Cross Section Ratio', 'Rmiss', 'Cross Section', 'Proton-Proton Scattering', 'Z Production', 'Invisible Z', 'Monojet', 'VBF', 'Invisible Higgs']}]
# LOCAL::location   :   Data from F4
# LOCAL::name   :   Table 1
# LOCAL::table_doi   :   10.17182/hepdata.78366.v2/t1
# GLOBAL::data_file   :   Table1.yaml
# GLOBAL::description   :   Measured and expected $R^\text{miss}$ as a function of $p_\text{T}^\text{miss}$ in the $\geq 1$ jet phase space. The fiducial SM predictions for the numerator and the denominator are also given.
# GLOBAL::keywords   :   [{'name': 'reactions', 'values': ['P P --> MET + J X', 'P P --> LEPTON+ LEPTON- J X']}, {'name': 'observables', 'values': ['PTMISS']}, {'name': 'cmenergies', 'values': [13000.0]}, {'name': 'phrases', 'values': ['Dark Matter', 'Fiducial Cross Section Ratio', 'Rmiss', 'Cross Section', 'Proton-Proton Scattering', 'Z Production', 'Invisible Z', 'Monojet', 'VBF', 'Invisible Higgs']}]
# GLOBAL::location   :   Data from F4
# GLOBAL::name   :   Table 1
# GLOBAL::table_doi   :   10.17182/hepdata.78366.v2/t1
# LOCAL::DEP_VARS::header   :   {'name': 'measured $R^\\text{miss}$'}
# LOCAL::DEP_VARS::qualifiers   :   [{'name': 'PHASE SPACE', 'value': '$\\geq 1$ JET'}, {'name': 'SQRT(S)', 'units': 'GEV', 'value': 13000}]
# LOCAL::INDEP_VARS::header   :   {'name': '$p_\\text{T}^\\text{miss}$', 'units': 'GEV'}

# %% [markdown]
# #### Now we can rename this table to something intelligible. Obviously I can't be bothered to do this for every table, every time, so instead I stored all of my keys in a config file, which I can load.

# %%
dataset.rename("|10.17182/hepdata.78366.v2/t1|Table1.yaml|measured $R^\\text{miss}$|","R_pT_miss_geq1j_meas")
dataset.load_keys("DM_paper_keys.dat")
# Out:
# INFO	Distribution_store.print_keys	keys for _distributions_1D are:
# R_pT_miss_geq1j_meas
# R_pT_miss_geq1j_exp
# R_pT_miss_VBF_meas
# R_pT_miss_VBF_exp
# R_m_jj_VBF_meas
# R_m_jj_VBF_exp
# R_dphi_jj_VBF_meas
# R_dphi_jj_VBF_exp
# pT_miss_ge1j_SM_num
# pT_miss_ge1j_SM_den
# pT_miss_VBF_SM_num
# pT_miss_VBF_SM_den
# m_jj_VBF_SM_num
# m_jj_VBF_SM_den
# dphi_jj_VBF_SM_num
# dphi_jj_VBF_SM_den
# INFO	Distribution_store.print_keys	keys for _distributions_2D are:
# stat_corr
# stat_cov
# syst_cov_lep_eff
# syst_cov_jets
# syst_cov_W->taunu_CR
# syst_cov_multijet
# syst_cov_corr_fac_stat
# syst_cov_W_stat
# syst_cov_W_theory
# syst_cov_top_xs
# syst_cov_Z->ll_bkg
# syst_cov_total
# INFO	Distribution_store.print_keys	2D distribution [key=stat_corr] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=stat_cov] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_lep_eff] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_jets] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_W->taunu_CR] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_multijet] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_corr_fac_stat] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_W_stat] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_W_theory] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_top_xs] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_Z->ll_bkg] with local-keys: []
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_total] with local-keys: []

# %% [markdown]
# #### I have some 2D distributions here. I happen to know (from their metadata) that these are correlation/covariance matrices. I want to associate them with the 1D distributions they describe. I can do this using my cleverly-chosen unique keys.

# %%
#  Set 2D table keys so I know what distribution they correspond to. First I need to print the meta_data so I know what they are.
dataset._distributions_2D["stat_corr"].set_local_key("garbage",0,10)
# oops, we set a rubbish key, let's remove it...
dataset._distributions_2D["stat_corr"].remove_local_key("garbage")
# if you want to change a local key name, you can
dataset._distributions_2D["stat_corr"].set_local_key("pT_miss",0,6)
dataset._distributions_2D["stat_corr"].change_local_key("pT_miss","pT_miss_geq1j")
# now to set the rest...
dataset._distributions_2D["stat_corr"].set_local_key("pT_miss_VBF",7,12)
dataset._distributions_2D["stat_corr"].set_local_key("m_jj_VBF",13,17)
dataset._distributions_2D["stat_corr"].set_local_key("dphi_jj_VBF",18,23)
# copy the local-keys from stat_corr into all other matrices
dataset.copy_2D_local_keys("stat_corr","stat_cov","syst_cov_lep_eff","syst_cov_jets","syst_cov_W->taunu_CR","syst_cov_multijet","syst_cov_corr_fac_stat","syst_cov_W_stat","syst_cov_W_theory","syst_cov_top_xs","syst_cov_Z->ll_bkg","syst_cov_total")
dataset.print_keys()
# Out:
# INFO	Distribution_store.print_keys	keys for _distributions_1D are:
# R_pT_miss_geq1j_meas
# R_pT_miss_geq1j_exp
# R_pT_miss_VBF_meas
# R_pT_miss_VBF_exp
# R_m_jj_VBF_meas
# R_m_jj_VBF_exp
# R_dphi_jj_VBF_meas
# R_dphi_jj_VBF_exp
# pT_miss_ge1j_SM_num
# pT_miss_ge1j_SM_den
# pT_miss_VBF_SM_num
# pT_miss_VBF_SM_den
# m_jj_VBF_SM_num
# m_jj_VBF_SM_den
# dphi_jj_VBF_SM_num
# dphi_jj_VBF_SM_den
# INFO	Distribution_store.print_keys	keys for _distributions_2D are:
# stat_corr
# stat_cov
# syst_cov_lep_eff
# syst_cov_jets
# syst_cov_W->taunu_CR
# syst_cov_multijet
# syst_cov_corr_fac_stat
# syst_cov_W_stat
# syst_cov_W_theory
# syst_cov_top_xs
# syst_cov_Z->ll_bkg
# syst_cov_total
# INFO	Distribution_store.print_keys	2D distribution [key=stat_corr] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']
# INFO	Distribution_store.print_keys	2D distribution [key=stat_cov] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_lep_eff] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_jets] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_W->taunu_CR] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_multijet] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_corr_fac_stat] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_W_stat] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_W_theory] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_top_xs] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_Z->ll_bkg] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']
# INFO	Distribution_store.print_keys	2D distribution [key=syst_cov_total] with local-keys: ['pT_miss_geq1j@[0, 6]', 'pT_miss_VBF@[7, 12]', 'm_jj_VBF@[13, 17]', 'dphi_jj_VBF@[18, 23]']

# %% [markdown]
# #### Now I can visualise the 1D distributions...

# %%
dataset.plot_1D_distribution("R_pT_miss_geq1j_meas",legend_loc="lower left",ylabel="R_miss (>=1j region)",xlabel="pT_miss  [GeV]",label="Measured",xlim=[200,1400],ylim=[0,13])

# %% [markdown]
# #### ... or take ratios...

# %%
dataset.plot_data_vs_prediction("R_pT_miss_geq1j_meas","R_pT_miss_geq1j_exp",legend_loc="lower left",ylabel="R_miss (>=1j region)",xlabel="pT_miss  [GeV]",xlim=[200,1400],ylim=[0,13])

# %%
dataset.plot_data_vs_prediction("R_pT_miss_VBF_meas","R_pT_miss_VBF_exp",legend_loc="lower left",ylabel="R_miss (VBF region)",xlabel="pT_miss  [GeV]",xlim=[200,1400],ylim=[0,13])
dataset.plot_data_vs_prediction("R_m_jj_VBF_meas","R_m_jj_VBF_exp",legend_loc="lower left",ylabel="R_miss (VBF region)",xlabel="m_jj  [GeV]",xlim=[200,4000],ylim=[0,13])
dataset.plot_data_vs_prediction("R_dphi_jj_VBF_meas","R_dphi_jj_VBF_exp",legend_loc="lower left",ylabel="R_miss (VBF region)",xlabel="Dphi_jj  [GeV]",xlim=[0,3.15],ylim=[0,13])

# %% [markdown]
# #### ... or plot 2D distributions...

# %%
dataset.plot_matrix("stat_corr",title="Statistical correlation",flt_precision=1)

# %%
dataset.plot_matrix("syst_cov_jets",title="Systematic covariance (jets)",flt_precision=2)

# %%
dataset.plot_matrix("syst_cov_Z->ll_bkg",title="Systematic covariance (Z->ll bkg)",flt_precision=2)

# %%
dataset.plot_matrix("syst_cov_total",title="Systematic covariance (total)",flt_precision=1)
