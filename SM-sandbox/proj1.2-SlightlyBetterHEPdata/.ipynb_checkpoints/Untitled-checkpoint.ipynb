# %%
import os, sys, yaml
import general_utils.messaging as msg
import general_utils.helpers as hlp
import HEP_data_utils.helpers as HEPData_hlp
from HEP_data_utils.data_structures import *

dataset = Distribution_store("Random plots")
HEPData_hlp.load_dataset ( dataset , "../HEP_datasets/HEPData-ins1312978-v1-yaml" )
dataset.print_all()
# Out:
# INFO	HEP_data_utils.helpers.load_dataset	../HEP_datasets/HEPData-ins1312978-v1-yaml is a directory... I am expanding the entries (but will only go one directory deep!)
# INFO	HEP_data_utils.helpers.load_dataset	submission.yaml file found in directory ../HEP_datasets/HEPData-ins1312978-v1-yaml... I will use this to steer the directory
# Distribution_store  [Random plots]
#    - 10.17182/hepdata.69473.v1
#    - https://atlas.web.cern.ch/Atlas/GROUPS/PHYSICS/PAPERS/HIGG-2013-08/
#    - web page with auxiliary material
#    - A measurement of the production processes of the recently discovered Higgs boson is performed in the two-photon final state using 5.4 fb-1 of proton-proton collisions data at sqrt(s)=7 TeV and 20.3 fb-1 at sqrt(s)=8 TeV collected by the ATLAS detector at the Large Hadron Collider.
#
#    - 1D distribution with key "|10.17182/hepdata.69473.v1/t1|Table1.yaml|SIGNAL STRENGTH|", name  "SIGNAL STRENGTH" and 12 bins
# ...

# %%
dataset.plot_all()

# %%
dataset.clear()
HEPData_hlp.load_dataset ( dataset , "../HEP_datasets/HEPData-ins1705857-v1-yaml" )
dataset.plot_all()
# Out:
# INFO	HEP_data_utils.helpers.load_dataset	../HEP_datasets/HEPData-ins1705857-v1-yaml is a directory... I am expanding the entries (but will only go one directory deep!)
# INFO	HEP_data_utils.helpers.load_dataset	submission.yaml file found in directory ../HEP_datasets/HEPData-ins1705857-v1-yaml... I will use this to steer the directory

# %%
dataset.clear()
HEPData_hlp.load_dataset ( dataset , "../HEP_datasets/HEPData-ins1306615-v2-yaml" )
dataset.plot_all()
# Out:
# INFO	HEP_data_utils.helpers.load_dataset	../HEP_datasets/HEPData-ins1705857-v1-yaml is a directory... I am expanding the entries (but will only go one directory deep!)
# INFO	HEP_data_utils.helpers.load_dataset	submission.yaml file found in directory ../HEP_datasets/HEPData-ins1705857-v1-yaml... I will use this to steer the directory
# INFO	HEP_data_utils.helpers.load_dataset	../HEP_datasets/HEPData-ins1306615-v2-yaml is a directory... I am expanding the entries (but will only go one directory deep!)
# INFO	HEP_data_utils.helpers.load_dataset	submission.yaml file found in directory ../HEP_datasets/HEPData-ins1306615-v2-yaml... I will use this to steer the directory
# ERROR	HEP_data_utils.helpers.set_1D_bins	Bin entry {'high': 100.0, 'low': 50.0} for distribution D(SIG)/DPT(2GAMMA) is not continuous from the previous bin which ended at 200.0
# ...
